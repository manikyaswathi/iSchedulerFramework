# %%
from DNNHelper import DNNHelper
import tensorflow as tf

# %%
dnnhelper = DNNHelper(signIn = True, credsFile="TAPISCreds.json")
# Out:
# ---------------------------------------------------------------------------
# ConfigurationError                        Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 dnnhelper = DNNHelper(signIn = True, credsFile="TAPISCreds.json")
#
# File ~/Documents/GitHub/TAPIS/DNNHelper/DNNHelper.py:44, in DNNHelper.__init__(self, signIn, credsFile)
#      41 # Execute Contaniers - estimators
#      42 self.exec_system_hpc = None
# ---> 44 self.dbhook = ComputingInfoDatabase()
#      45 self.model_predictor = ModelEstimator("RespurceEstimator", "nopathyet")
#      46 self.model_predictorWaitTimes = ModelEstimator("Waitime predictor", "nopathyet")
#
# File ~/Documents/GitHub/TAPIS/DNNHelper/GetResourceEstimator/Estimators.py:49, in ComputingInfoDatabase.__init__(self, modelPath)
#      48 def __init__(self, modelPath=None):
# ---> 49     self.cluster = MongoClient("mongodb+srv://harpuser:harpuser@harp.afryura.mongodb.net/?retryWrites=true&w=majority&appName=HARP")
# ...

# %%
# Traning Data
fashion_mnist = tf.keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
train_images = train_images / 255.0
test_images = test_images / 255.0



# Traning Data
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10)
])
print("***********************\n")
model.summary()
print("\n**********************\n")

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
# Out:
# ***********************
#
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_2 (Dense)             (None, 128)               100480
#
#  dense_3 (Dense)             (None, 10)                1290
#
# ...
# Total params: 101770 (397.54 KB)
# Trainable params: 101770 (397.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
# **********************

# %%
model_JSON = dnnhelper.getModelSummaryJSON(model)

# path_to_image = "PATH TO THE CREATED CONTAMNIER IMAGE"
# dnnhelper.createAppDefinition(path_to_image, model_JSON)

traning_metadata = {
    "w":"256",
    "h":"256",
    "c":"3",
    "traning":"2000",
    "validation":"0"
}

queue_vs_timecost = dnnhelper.getFeasibleQueues(modelJSON=model_JSON, TraningMetsData=traning_metadata)

for i in queue_vs_timecost:
    print(i)
# Out:
# {'_id': ObjectId('66047ac21ac8ad18b092cd36'), 'cluster_name': 'ascend', 'batchLogical Queue Name': 'batch', 'minNodeCount': 0, 'maxNodeCount': 4, 'minCoresPerNode': 1, 'maxCoresPerNode': 96, 'minMemoryMB': 0, 'maxMemoryMB': 936562, 'minMinutes': 0, 'maxMinutes': 10080, 'Feasible': 'Yes', 'Cost': 93.52}
# {'_id': ObjectId('66047ac21ac8ad18b092cd37'), 'cluster_name': 'ascend', 'batchLogical Queue Name': 'cpuonly', 'minNodeCount': 0, 'maxNodeCount': 4, 'minCoresPerNode': 1, 'maxCoresPerNode': 84, 'minMemoryMB': 0, 'maxMemoryMB': 900816, 'minMinutes': 0, 'maxMinutes': 5760, 'Feasible': 'Yes', 'Cost': 101.86999999999999}
# {'_id': ObjectId('66047ac21ac8ad18b092cd38'), 'cluster_name': 'ascend', 'batchLogical Queue Name': 'debug', 'minNodeCount': 0, 'maxNodeCount': 2, 'minCoresPerNode': 1, 'maxCoresPerNode': 88, 'minMemoryMB': 0, 'maxMemoryMB': 943712, 'minMinutes': 0, 'maxMinutes': 60, 'Feasible': 'No', 'Cost': 0}
# ...

# %%
system_vs_timecost = dnnhelper.getFeasibleSystems(queue_vs_timecost=queue_vs_timecost)

for i in system_vs_timecost:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 system_vs_timecost = dnnhelper.getFeasibleSystems(queue_vs_timecost=queue_vs_timecost)
#       3 for i in system_vs_timecost:
#       4     print(i)
#
# AttributeError: 'DNNHelper' object has no attribute 'getFeasibleSystems'
